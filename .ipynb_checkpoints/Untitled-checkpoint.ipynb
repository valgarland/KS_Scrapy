# %%
import pandas as pd
df = pd.read_csv('kitchenstories_30102020.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                                                 author  \
# 0                                                Kohei
# 1                                       Sinead Sweeney
# 2                                         Enikö Gruber
# 3                                        Christian Ruß
# 4                                      Sandra Schumann
# 5                                       Devan Grimsrud
# 6                                                 Lisa
# 7                                               Verena
# 8                                          Alex Hiller
# 9                                               Ramona
# 10                                      nathan peyzner
# 11                                                  la
# 12                                   Roxanne De Weerdt
# 13                            Cesar Martinez Dominguez
# 14                                            RoselynJ
# 15                                    Nicolas St-Amour
# ...

# %%
test = ['4', '6', '2', '2', '2', '3', '4', 0, 0, 0, 0]

# %%
[float(i) for i in test]
# Out:
# [4.0, 6.0, 2.0, 2.0, 2.0, 3.0, 4.0, 0.0, 0.0, 0.0, 0.0]

# %%
test2 = 'clams,rice,garlic,green zucchinis,canned diced tomatoes,vegetable broth,white wine,dill,olive oil,salt,pepper,butter'

# %%
type(df['ingredient_unit'][0])
# Out:
# str
