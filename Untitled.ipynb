# %%
import pandas as pd
df = pd.read_csv("kitchenstories_30102020.csv")

# %%
df
# Out:
#             author                                       author_type  \
# 0          Yingpin                                  Community Member
# 1    Lisa Schölzel             Senior Food Editor at Kitchen Stories
# 2      Alex Hiller                                       Contributor
# 3   Devan Grimsrud                Managing Editor at Kitchen Stories
# 4      Alex Hiller                                       Contributor
# 5     Vanessa Pass                                       Contributor
# 6             Lisa                                       Contributor
# 7    Johanna Reder  Test Kitchen Manager and Chef at Kitchen Stories
# 8      Alex Hiller                                       Contributor
# 9     Enikö Gruber                                       Contributor
# 10  Devan Grimsrud                Managing Editor at Kitchen Stories
# 11     Alex Hiller                                       Contributor
# 12  Kristin Bothor                Managing Editor at Kitchen Stories
# ...
